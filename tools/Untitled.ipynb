# %%
import skvideo.io
#import skvideo.datasets
videogen = skvideo.io.vreader("/root/data/demo/1920-1080-4splits.avi")
for frame in videogen:
        print(frame.shape)
# Out:
# /usr/local/lib/python2.7/dist-packages/skvideo/__init__.py:356: UserWarning: avconv/avprobe not found in path:
#   warnings.warn("avconv/avprobe not found in path: " + str(path), UserWarning)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.imshow(frame)

# %%
frame
# Out:
# array([[[  3,  12,   0],
#         [  3,  12,   0],
#         [  0,  14,   0],
#         ...,
#         [ 36,  37,  30],
#         [ 36,  37,  30],
#         [ 36,  37,  30]],
#
#        [[  3,  12,   0],
#         [  3,  12,   0],
#         [  0,  14,   0],
#         ...,
#         [ 36,  37,  30],
#         [ 36,  37,  30],
#         [ 36,  37,  30]],
#
#        [[  7,   9,   0],
#         [  7,   9,   0],
#         [  3,  12,   0],
#         ...,
#         [ 38,  35,  30],
#         [ 38,  35,  30],
#         [ 38,  35,  30]],
#
#        ...,
#        [[165, 167, 163],
#         [165, 167, 163],
#         [166, 168, 164],
#         ...,
#         [175, 182, 178],
#         [175, 182, 178],
#         [175, 182, 178]],
#
#        [[165, 167, 163],
#         [165, 167, 163],
#         [166, 168, 164],
#         ...,
#         [175, 182, 178],
#         [175, 182, 178],
#         [175, 182, 178]],
#
#        [[165, 167, 163],
#         [165, 167, 163],
#         [166, 168, 164],
# ...

# %%
import cv2

# %%
img  = cv2.imread("2017-10-26.jpg")

# %%
plt.imshow(img)
